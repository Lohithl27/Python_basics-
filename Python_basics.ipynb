# %% [markdown]
# <a href="https://colab.research.google.com/github/Lohithl27/Python_basics-/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO 🌎")
# Out:
# HELLO 🌎

# %%
def greet():
    print("Hello World")

greet()
# Out:
# Hello World

# %%
def greet (name):
    print("Hello", name)

greet("CSE")
greet("CSD")
greet("Civil")
greet("Mechanical")
# Out:
# Hello CSE
# Hello CSD
# Hello Civil
# Hello Mechanical

# %%
def add(a,b):
    return a+b

result = add(5,3)
print(result)
# Out:
# 8

# %%
print("Rino")
# Out:
# Rino

# %%
name = "rino"
year = "2026"

print("Hello",name)
print(year)
# Out:
# Hello rino
# 2026

# %%
A = 25
B = 5

print("add",A + B)
print("sub",A - B)
# Out:
# add 30
# sub 20

# %%
A = input("Enter Your Name")
B = input("Enter Your Branch")

print ("Hello",A)
print("My Branch is",B)
# Out:
# Enter Your NameTino
# Enter Your BranchR&A
# Hello Tino
# My Branch is R&A

# %%
A = int(input("Enter Your 1st Number"))
B = int(input("Enter Your 2nd Number"))

print (A)
print(B)
print(A+B)
# Out:
# Enter Your 1st Number24
# Enter Your 2nd Number56
# 24
# 56
# 80

# %%
Age = int(input("Enter Your Age:"))

if Age>=18:
   print("You Can Vote 🤝")

else:
    print("Come Again Next year🖐️")
# Out:
# Enter Your Age:12
# Come Again Next year🖐️
